# %% [markdown]
# # STC Jawwy

# %%
# !pip install pyxlsb
# !pip install pandas --upgrade
# !pip install pandas pyxlsb numpy nltk

# %%
import pyxlsb
import numpy as np
import pandas as pd

# %% [markdown]
# # Jawwy dataset
# The dataset consists of details about each customer and the movies and/or tv shows watched in addition to the genre.
#
# You are required to work on task three to build a recommendation engine for our platform to Recommend movies to usesrs that they might be interested in¶

# %%
df= pd.read_excel('/content/stc TV Data Set_T3.xlsb', engine='openpyxl')

# %%
df.shape
# Out:
# (1048575, 6)

# %%
df.head()
# Out:
#    Unnamed: 0  user_id_maped          program_name  rating      date_  \
# 0           0          26138            100 treets       1 2017-05-27
# 1           1           7946                 Moana       1 2017-05-21
# 2           2           7418  The Mermaid Princess       1 2017-08-10
# 3           3          19307  The Mermaid Princess       2 2017-07-26
# 4           4          15860             Churchill       2 2017-07-07
#
#   program_genre
# 0         Drama
# 1     Animation
# 2     Animation
# 3     Animation
# 4     Biography

# %%
df.describe()
# Out:
#          Unnamed: 0  user_id_maped        rating  \
# count  1.048575e+06   1.048575e+06  1.048575e+06
# mean   5.242870e+05   1.709266e+04  2.497283e+00
# min    0.000000e+00   1.000000e+00  1.000000e+00
# 25%    2.621435e+05   8.253000e+03  1.000000e+00
# 50%    5.242870e+05   1.714900e+04  2.000000e+00
# 75%    7.864305e+05   2.566500e+04  3.000000e+00
# max    1.048574e+06   3.428000e+04  4.000000e+00
# std    3.026977e+05   1.003513e+04  1.119837e+00
#
#                                date_
# count                        1048575
# mean   2017-10-04 00:23:20.346183936
# min              2017-03-14 00:00:00
# 25%              2017-06-10 00:00:00
# 50%              2017-10-14 00:00:00
# 75%              2018-01-21 00:00:00
# max              2018-04-30 00:00:00
# std                              NaN

# %%
df.isnull().any()
# Out:
# Unnamed: 0       False
# user_id_maped    False
# program_name     False
# rating           False
# date_            False
# program_genre    False
# dtype: bool

# %%
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
"""
TODO build your Recommender system to Highlight Programs that usesrs might be interested in
"""
# Out:
# '\nTODO build your Recommender system to Highlight Programs that usesrs might be interested in\n'

# %%
# !pip install scikit-surprise

# %%
import pandas as pd
from surprise import Reader, Dataset, SVD
from surprise.model_selection import train_test_split


reader = Reader(rating_scale=(1, 5))

data = Dataset.load_from_df(df[['user_id_maped', 'program_name', 'rating']], reader)


trainset, testset = train_test_split(data, test_size=0.2)

algo = SVD()
algo.fit(trainset)

# Get recommendations for a specific user
user_id = 26138
program_names = df['program_name'].unique()
program_ids = [trainset.to_inner_iid(program_name) for program_name in program_names if program_name in trainset._raw2inner_id_items]
user_ratings = [algo.predict(user_id, program_id).est for program_id in program_ids]
program_ratings = list(zip(program_names, user_ratings))
top_recommendations = sorted(program_ratings, key=lambda x: x[1], reverse=True)[:5]

# Print the top recommendations
print("Top Recommendations for User", user_id)
for recommendation in top_recommendations:
    program_name = recommendation[0]
    predicted_rating = recommendation[1]
    print(f"Program: {program_name}, Predicted Rating: {predicted_rating}")
# Out:
# Top Recommendations for User 26138
# Program: 100 treets, Predicted Rating: 2.244162765721131
# Program: Moana, Predicted Rating: 2.244162765721131
# Program: The Mermaid Princess, Predicted Rating: 2.244162765721131
# Program: Churchill, Predicted Rating: 2.244162765721131
# Program: Beavis And Butt-Head Do America, Predicted Rating: 2.244162765721131

# %%
df.head()
# Out:
#    Unnamed: 0  user_id_maped          program_name  rating      date_  \
# 0           0          26138            100 treets       1 2017-05-27
# 1           1           7946                 Moana       1 2017-05-21
# 2           2           7418  The Mermaid Princess       1 2017-08-10
# 3           3          19307  The Mermaid Princess       2 2017-07-26
# 4           4          15860             Churchill       2 2017-07-07
#
#   program_genre
# 0         Drama
# 1     Animation
# 2     Animation
# 3     Animation
# 4     Biography

# %%
"""
TODO show the recommendations (top 5) for the people who watched "Moana" movie
"""
# Out:
# '\nTODO show the recommendations (top 5) for the people who watched "Moana" movie\n'

# %%
import pandas as pd
from surprise import Reader, Dataset, SVD
from surprise.model_selection import train_test_split


# Create the Surprise reader and dataset
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['user_id_maped', 'program_name', 'rating']], reader)

# Split the data into training and testing sets
trainset, testset = train_test_split(data, test_size=0.2)

# Train the SVD algorithm
algo = SVD()
algo.fit(trainset)

# Find the program ID for "Moana"
moana_program_id = trainset.to_inner_iid("Moana")

# Find users who watched "Moana"
users_who_watched_moana = [uid for (uid, iid, rating) in trainset.all_ratings() if iid == moana_program_id]

# Generate recommendations for each user who watched "Moana"
recommendations = []
for user_id in users_who_watched_moana:
    # Get the list of program IDs for which the user has not provided ratings
    program_ids = [iid for iid in trainset.all_items() if (user_id, iid) not in trainset.ur]

    # Predict ratings for the programs and sort them in descending order
    program_ratings = [(trainset.to_raw_iid(iid), algo.predict(user_id, iid).est) for iid in program_ids]
    top_recommendations = sorted(program_ratings, key=lambda x: x[1], reverse=True)[:5]

    # Add the recommendations to the list
    recommendations.extend(top_recommendations)

# Sort the recommendations by predicted rating in descending order
recommendations = sorted(recommendations, key=lambda x: x[1], reverse=True)

# Print the top 5 recommendations for people who watched "Moana"
print("Top Recommendations for People who watched 'Moana':")
for recommendation in recommendations[:5]:
    program_id = recommendation[0]
    predicted_rating = recommendation[1]
    program_info = df[df['program_name'] == program_id][['program_name', 'program_genre']].iloc[0]
    program_name = program_info['program_name']
    program_genre = program_info['program_genre']
    print(f"Program: {program_name}, Genre: {program_genre}")
# Out:
# Top Recommendations for People who watched 'Moana':
# Program: Borj Al Oloum  Ep., Genre: Animation
# Program: Wolverine and the X Men      Thieves Gambit, Genre: Animation
# Program: Slugterra     Mario Bravado, Genre: Animation
# Program: House  Alone, Genre: Drama
# Program: Pingu, Genre: Animation
